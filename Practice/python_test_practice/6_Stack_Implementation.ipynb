# %% [markdown]
# ### Q1
# **Problem:** Define a `Stack` class that initializes an empty list to store stack elements.

# %%
class Stack:
    def __init__(self, capacity):
        self.capacity = capacity
        self.stack = []
        self.top = -1

    def push(self, item):
        if len(self.stack) == self.capacity:
            raise Exception("Stack Overflow")
        else:
            self.stack.append(item)
            self.top += 1

    def pop(self):
        if self.top == -1:
            raise Exception("Stack Underflow")
        else:
            self.top -= 1
            return self.stack.pop()

    def peek(self):
        return self.stack[self.top]

    def is_empty(self):
        return len(self.stack) == 0

    def size(self):
        return len(self.stack)

    def display(self):
        for i in range(self.top + 1):
            print(self.stack[i])

# %% [markdown]
# ### Q2
# **Problem:** Implement the `push(item)` method to add an item to the top of the stack.

# %% [markdown]
# ### Q3
# **Problem:** Implement the `pop()` method. Ensure it returns an appropriate message or raises an error if the stack is underflowed (empty).

# %% [markdown]
# ### Q4
# **Problem:** Implement the `peek()` method to return the top element without removing it.

# %% [markdown]
# ### Q5
# **Problem:** Implement an `is_empty()` method returning a boolean indicating if the stack has no elements.

# %% [markdown]
# ### Q6
# **Problem:** Implement a `size()` method that returns the current number of elements in the stack.

# %% [markdown]
# ### Q7
# **Problem:** Using your `Stack` class, write a separate function `reverse_string(text)` that reverses a string using stack operations.

# %% [markdown]
# ### Q8
# **Problem:** Using your `Stack` class, write a function `is_balanced(expression)` to check if a string of parentheses '()', '{}', '[]' is balanced.

# %% [markdown]
# ### Q9
# **Problem:** Modify the `Stack` class to include a `get_min()` method that returns the minimum element in the stack in O(1) time.

# %% [markdown]
# ### Q10
# **Problem:** Write a function `sort_stack(stack)` that sorts the elements in a stack using only one additional auxiliary stack.
