# %%
freq = dict()

arr = [1, 2, 1, 3]

for i in arr:
	if i not in freq:
		freq[i] = 1
	else:
		freq[i] += 1
		
print(freq)
# Out:
# {1: 2, 2: 1, 3: 1}

# %%
t = (1, 2, 3)
t += (4,)
print(t)
# Out:
# (1, 2, 3, 4)

# %%
target_list = [1, 2, 3, 4, 5]

odd_sq = map(lambda x: x*x,
             filter(lambda x: x % 2 != 0, target_list))

print(list(odd_sq))
print(list(odd_sq))
# Out:
# [1, 9, 25]
# []

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
lst = [1, 2, 3]
print(lst * 2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a = [1, 2, 3]
def f(x):
    x.append(99)

f(a)
print(a)
# Out:
# [1, 2, 3, 99]

# %%
t = (1, 2, 3)
t += (4, )
print(t)
# Out:
# (1, 2, 3, 4)

# %%
a = [1, 2, 3]
b = a
b = b + [4]
print(a)
print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
a = [[1, 2], [3, 4]]
b = a[:]
b[0].append(99)
print(a)
# Out:
# [[1, 2, 99], [3, 4]]

# %%
a = [[1, 2], [3, 4]]
b = a[:]
b[0] = [9, 9]
print(a)
# Out:
# [[1, 2], [3, 4]]

# %%
l = [3, 6, 9, 12, 15, 18]
l_even = [x for x in l if x % 2 == 0]
print(l)
print(l_even)
# Out:
# [3, 6, 9, 12, 15, 18]
# [6, 12, 18]

# %%
l = [1, 2, 3, 4, 5, 6]
l_sq = [x*x for x in l if x % 2 != 0]
print(l)
print(l_sq)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 9, 25]

# %%
l = [-3, 0, 4, -1, 7]
l_out = [x for x in l if x > 0 x = "P" if x < 0 x = "N" if x = "z"]
# Out:
#   Cell In[19], line 2
#     l_out = [x for x in l if x > 0 x = "P" if x < 0 x = "N" if x = "z"]
#                                    ^
# SyntaxError: invalid syntax

# %%
l = [[1, 4], [2, 6, 3], [7]]
flat = [y for x in l for y in x if y > 3]

print(l)
print(flat)
# Out:
# [[1, 4], [2, 6, 3], [7]]
# [4, 6, 7]

# %%
words = ["apple", "banana", "orange", "grape", "umbrella"]
vowels = set([v for word in words for v in word if v in "aeiou"])

print(words)
print(vowels)
# Out:
# ['apple', 'banana', 'orange', 'grape', 'umbrella']
# {'a', 'u', 'e', 'o'}

# %% [markdown]
# Q. Write a function to count the number of digits in a number.

# %%
def count(n):
    c = 0
    while n != 0:
        c += 1
        n //= 10
    return c

def main():
    num = int(input("Enter a number: "))
    print(f"Number of digits in {num} is {count(num)}")

if __name__ == "__main__":
    main()
# Out:
# Number of digits in 1234 is 4

# %%
def is_prime(n):
    if n == 2 or n == 3:
        return True

    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def main():
    num = int(input("Enter a number: "))
    if is_prime(num):
        print(f"{num} is a prime number.")
    else:
        print(f"{num} is not a prime number.")

if __name__ == "__main__":
    main()
# Out:
# 8 is not a prime number.

# %% [markdown]
# Write a fucntion for an integer which Q. prints it's multiplication table upto 10.

# %%
def print_table(n, r=10):
    for i in range(1, r + 1):
        print(f"{n} x {i} = {n * i}")

print_table(7)
print()
print_table(5, 12)
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
# 5 x 11 = 55
# 5 x 12 = 60

# %%
def is_prime(n):
    if n == 2 or n == 3:
        return True

    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True


def main():
    lst = []
    n = int(input("Lenght of List:"))

    for _ in range(1, n + 1):
        num = int(input("Enter a number: "))
        lst.append(num)
    print(lst)

    # primes = [x for x in lst if is_prime(x)]
    primes = list(filter(is_prime, lst))
    print(primes)

if __name__ == "__main__":
    main()
# Out:
# [2, 3, 5, 12, 4]
# [2, 3, 5]

# %% [markdown]
# Input: a natural number
#
# Keys: Prime factors <br>
# Values: Frequency of factors
#
# <br><br>
# eg: input: 28<br>
# output: {2: 2, 7: 1}

# %%
def is_prime(n):
    if n == 2 or n == 3:
        return True

    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def prime_factors(n):
    d = {}
    for i in range(2, n):
        if is_prime(i) and n % i == 0:
            c, num = 0, n
            while num % i == 0:
                c += 1
                num //= i
            d[i] = d.get(i, 0) + c

    return d

def main():
    n = int(input("Number: "))
    print(prime_factors(n))

if __name__ == "__main__":
    main()
# Out:
# {2: 5, 3: 1}

# %%
def rev(n):
    rev = 0
    while n != 0:
        r = n % 10
        rev = rev * 10 + r 
        n //= 10
    
    return rev

def main():
    n = int(input("n:"))
    print(rev(n))

if __name__ == "__main__":
    main()
# Out:
# 54321

# %%
import random
callable_random = [f for f in dir(random) if callable(getattr(random, f))]
print(callable_random)
print(help(random.sample))

funcs = random.sample(callable_random, k=5)
print(funcs)
# Out:
# ['Random', 'SystemRandom', '_Sequence', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_exp', '_fabs', '_floor', '_index', '_isfinite', '_lgamma', '_log', '_log2', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', '_warn', 'betavariate', 'binomialvariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'normalvariate', 'paretovariate', 'randbytes', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']
# Help on method sample in module random:
#
# sample(population, k, *, counts=None) method of random.Random instance
#     Chooses k unique random elements from a population sequence.
#
#     Returns a new list containing elements from the population while
#     leaving the original population unchanged.  The resulting list is
#     in selection order so that all sub-slices will also be valid random
# ...

# %%
import os 

print(os.getcwd())
print(os.listdir())

for file in os.listdir():
    if os.path.isfile(file):
        print(file)

    if os.path.isdir(file):
        print(f"FOLDER PATH: {os.path.join(os.getcwd(), file)}")

# %%
print(getattr(random, 'randint'))
print(callable(getattr(random, 'randint')))
# Out:
# <bound method Random.randint of <random.Random object at 0x5bc3e53680c0>>
# True
